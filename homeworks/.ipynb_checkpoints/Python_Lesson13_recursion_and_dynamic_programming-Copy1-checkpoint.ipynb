# %% [markdown]
# # Recursion

# %%
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n - 1)

# %%
factorial(1000)
# Out:
# ...

# %%
from functools import reduce
def factorial(n):
    return reduce(lambda x, y: x * y, range(n, 0, -1))

# %%
factorial(1000)
# Out:
# ...

# %% [markdown]
# # Fibonacci Number

# %%
def fibonacci(n):
    if n < 2:
        return n
    result = fibonacci(n-1) + fibonacci(n-2)
    return result

fibonacci(30)
# Out:
# 832040

# %% [markdown]
# # Memorization

# %%
cache = {}
def fibonacci(n):
    if n in cache:
        return cache[n]
    if n < 2:
        return n
    result = fibonacci(n-1) + fibonacci(n-2)
    cache[n] = result
    return result

fibonacci(30)
# Out:
# 832040

# %% [markdown]
# ## Tabulation

# %%
def fibonacci(n):
    results = [0, 1]
    for i in range(2, n + 1):
        results.append(results[i - 1] + results[i - 2])
    return results[n]

# %%
fibonacci(30)
# Out:
# 832040

# %% [markdown]
# # 練習

# %% [markdown]
# ## Fibonacci Number
# ```
# n = 5
# print 0, 1, 1, 2, 3, 5
# ```

# %%
def fibonacci(n):
    results = [0, 1]
    for i in range(2, n + 1):
        results.append(results[i - 1] + results[i - 2])
    return results

print(fibonacci(5))
# Out:
# [0, 1, 1, 2, 3, 5]

# %% [markdown]
# ## 爬階梯

# %% [markdown]
# ```
# 爬階梯，一次只能爬一格或兩格
# 若給定階梯數 n，請問有幾種不重複的爬階梯組合？
# ```

# %% [markdown]
# ### example1:
# ```
#     Input: n = 2
#     Output: 2
#     Explanation: There are two ways to climb to the top.
#     1. 1 step + 1 step
#     2. 2 steps
# ```
#
# ### example2:
# ```
#     Input: n = 3
#     Output: 3
#     Explanation: There are three ways to climb to the top.
#     1. 1 step + 1 step + 1 step
#     2. 1 step + 2 steps
#     3. 2 steps + 1 step
# ```

# %%
def climb_stairs(n):
    def return_steps(k):
        if k < 2:
            return k
        result = return_steps(k-1) + return_steps(k-2)
        return result
    return return_steps(n+1)

# %%
climb_stairs(5)
# Out:
# 8
